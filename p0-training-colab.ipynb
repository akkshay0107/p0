# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !curl -fsSL https://deb.nodesource.com/setup_20.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# 2026-06-10 19:52:56 - Installing pre-requisites
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,719 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,006 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,183 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,052 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,357 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,489 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,608 kB]
# Fetched 42.5 MB in 4s (9,719 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 74 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.24).
# gnupg is already the newest version (2.2.27-3ubuntu2.5).
# gnupg set to manually installed.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 74 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 170 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 apt-transport-https all 2.4.14 [1,510 B]
# Fetched 1,510 B in 0s (39.0 kB/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.14_all.deb ...
# Unpacking apt-transport-https (2.4.14) ...
# Setting up apt-transport-https (2.4.14) ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:9 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [14.7 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 30.7 kB in 1s (22.2 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 74 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 2026-06-10 19:53:14 - Repository configured successfully.
# 2026-06-10 19:53:14 - To install Node.js, run: apt install nodejs -y
# 2026-06-10 19:53:14 - You can use N|solid Runtime as a node.js alternative
# 2026-06-10 19:53:14 - To install N|solid Runtime, run: apt install nsolid -y
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 74 not upgraded.
# Need to get 32.2 MB of archives.
# After this operation, 196 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.20.2-1nodesource1 [32.2 MB]
# Fetched 32.2 MB in 1s (44.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 122407 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.20.2-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.20.2-1nodesource1) ...
# Setting up nodejs (20.20.2-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !node -v && npm -v
# Out:
# v20.20.2
# 10.8.2

# %%
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.11.20-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.11.20-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 74.5 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.11.20

# %%
# !git clone https://github.com/akkshay0107/p0.git
# Out:
# Cloning into 'p0'...
# remote: Enumerating objects: 2059, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 2059 (delta 131), reused 111 (delta 64), pack-reused 1842 (from 1)
# Receiving objects: 100% (2059/2059), 2.92 MiB | 7.77 MiB/s, done.
# Resolving deltas: 100% (1469/1469), done.

# %%
# !cd p0 && git checkout champions-port
# Out:
# Branch 'champions-port' set up to track remote branch 'champions-port' from 'origin'.
# Switched to a new branch 'champions-port'

# %%
# !cd p0 && git log -n 5
# Out:
# commit 328cf125712d4b04284c918d51910cf23ee3f503 (HEAD -> champions-port, origin/champions-port)
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Thu Jun 11 01:08:03 2026 +0530
#
#     make benchmarks manage their own ps server
#
# commit 5ad7be949e21755a09c708c61f1d09c46d4a21d7
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Thu Jun 11 00:56:10 2026 +0530
#
#     fix selected pokemon bug
#
# commit 6e2e24463fb6bd995e5a6c8a6918a8563ff4e2d9
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Thu Jun 11 00:07:46 2026 +0530
#
#     fix memory tokens init
#
# commit 0b7a59337e3f7915fb8f9c1350c7210bf3da7e54
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Wed Jun 10 23:37:36 2026 +0530
#
#     update pfsp weight, kl early stop, obs builder edge cases
#
# commit 99e1c286757ec4c9f26ba63d8f53bba899e5286e
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Wed Jun 10 23:15:30 2026 +0530
#
#     per channel history gate

# %%
# !cd p0 && git submodule update --init --recursive
# Out:
# Submodule 'pokemon-showdown' (https://github.com/smogon/pokemon-showdown.git) registered for path 'pokemon-showdown'
# Cloning into '/content/p0/pokemon-showdown'...
# Submodule path 'pokemon-showdown': checked out 'd62d3a39878f7ef1c6e1cfbd84e8feb2ce7a9fdd'

# %%
# !cd p0/pokemon-showdown && npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇npm warn deprecated npmlog@6.0.2: This package is no longer supported.
# ⠇npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙npm warn deprecated are-we-there-yet@3.0.1: This package is no longer supported.
# ⠙⠹npm warn deprecated gauge@4.0.4: This package is no longer supported.
# ⠹npm warn deprecated @npmcli/move-file@1.1.2: This functionality has been moved to @npmcli/fs
# ⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 355 packages, and audited 356 packages in 10s
# ⠼
# ⠼72 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# 23 vulnerabilities (3 low, 8 moderate, 12 high)
#
# To address issues that do not require attention, run:
#   npm audit fix
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠼

# %%
# !cd p0 && uv python install 3.13 && uv sync --extra cuda
# Out:
# Installed Python 3.13.13 in 1.66s
#  + cpython-3.13.13-linux-x86_64-gnu (python3.13)
# warning: `/root/.local/bin` is not on your PATH. To use installed Python executables, run `export PATH="/root/.local/bin:$PATH"` or `uv python update-shell`.
# Using CPython 3.13.13
# Creating virtual environment at: .venv
# Resolved 61 packages in 1ms
# Prepared 58 packages in 51.55s
# Installed 58 packages in 406ms
#  + absl-py==2.4.0
#  + certifi==2026.5.20
#  + charset-normalizer==3.4.7
#  + cloudpickle==3.1.2
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.4
#  + cuda-toolkit==13.0.2
#  + farama-notifications==0.0.6
#  + filelock==3.29.0
#  + fsspec==2026.4.0
#  + grpcio==1.80.0
#  + gymnasium==1.3.0
#  + idna==3.16
#  + iniconfig==2.3.0
#  + jinja2==3.1.6
#  + markdown==3.10.2
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.6
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.1
#  + nvidia-nccl-cu13==2.29.7
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + orjson==3.11.9
#  + p0==0.1.0 (from file:///content/p0)
#  + packaging==26.2
#  + pettingzoo==1.26.1
#  + pillow==12.2.0
#  + pluggy==1.6.0
#  + poke-env==0.15.0
#  + protobuf==7.35.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + pytest-asyncio==1.4.0
#  + requests==2.34.2
#  + setuptools==81.0.0
#  + sympy==1.14.0
#  + tabulate==0.10.0
#  + tensorboard==2.20.0
#  + tensorboard-data-server==0.7.2
#  + torch==2.12.0
#  + triton==3.7.0
#  + typing-extensions==4.15.0
#  + urllib3==2.7.0
#  + websockets==16.0
#  + werkzeug==3.1.8

# %%
# %%writefile /content/p0/.ppoconfig
# num_episodes=40
# warmup_episodes=0
# lr=3e-5
# snapshot_interval=20
# Out:
# Writing /content/p0/.ppoconfig

# %%
! cd p0 && uv run bench/benchmark_action_time.py
# Out:
# [Showdown Server] Building pokemon-showdown in /content/p0/pokemon-showdown...
# [Showdown Server] Pokemon-showdown built successfully.
# [Showdown Server] Starting Showdown server on port 8000...
# [Showdown Server] Showdown server is ready on port 8000.
# Using device: cuda
# Starting 5 battles to profile the forward pass...
#
# ==================== cProfile Results for RL_Profiler ====================
# Total _get_action calls: 45
#          1657485 function calls (1643604 primitive calls) in 3.292 seconds
#
#    Ordered by: internal time
#    List reduced from 378 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2610    0.269    0.000    0.269    0.000 {built-in method torch._C._nn.linear}
#     24414    0.144    0.000    1.145    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:1171(synchronize)
#       765    0.129    0.000    0.129    0.000 {built-in method torch.embedding}
#     48828    0.124    0.000    0.558    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:168(is_available)
#     24414    0.096    0.000    0.096    0.000 {built-in method torch._C._cuda_synchronize}
#     48828    0.093    0.000    0.189    0.000 <frozen os>:712(__getitem__)
#        45    0.085    0.002    0.203    0.005 /content/p0/src/model/policy.py:191(_build_action_context)
#    224479    0.085    0.000    0.085    0.000 {built-in method builtins.isinstance}
#     24414    0.081    0.000    0.760    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/_utils.py:557(_get_device_index)
#     24414    0.077    0.000    0.623    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/_utils.py:849(_get_device_index)
#     48828    0.072    0.000    0.261    0.000 <frozen _collections_abc>:808(get)
#        90    0.062    0.001    0.062    0.001 {built-in method torch.multinomial}
#     48828    0.061    0.000    0.096    0.000 <frozen os>:794(encode)
#     24414    0.058    0.000    0.488    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/_utils.py:807(_get_device_attr)
#        45    0.056    0.001    0.676    0.015 /content/p0/src/model/fused_token_encoder.py:294(forward)
#        45    0.054    0.001    0.068    0.002 /content/p0/src/model/policy.py:360(_apply_sequential_masks)
#     48828    0.049    0.000    0.310    0.000 <frozen os>:811(getenv)
#        45    0.048    0.001    0.495    0.011 /content/p0/src/model/fused_token_encoder.py:216(_embed_pokemon_super)
#     24414    0.047    0.000    1.476    0.000 /content/p0/bench/benchmark_action_time.py:33(get_time)
#     48828    0.045    0.000    0.355    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:164(_nvml_based_avail)
#     48828    0.039    0.000    0.057    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:159(_is_compiled)
#     48828    0.038    0.000    0.087    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:463(_lazy_init)
#     24414    0.038    0.000    0.100    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:1165(current_device)
#       540    0.037    0.000    0.037    0.000 {built-in method torch.where}
#        90    0.033    0.000    0.033    0.000 {built-in method torch.sort}
#     24414    0.032    0.000    0.047    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:619(__exit__)
# 11937/9861    0.032    0.000    1.548    0.000 /content/p0/bench/benchmark_action_time.py:56(wrapped)
#       585    0.031    0.000    0.031    0.000 {built-in method torch.layer_norm}
#     48828    0.030    0.000    0.050    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:414(is_initialized)
#       990    0.030    0.000    0.030    0.000 {built-in method torch._C._nn.gelu}
#       540    0.029    0.000    0.083    0.000 /content/p0/src/model/observation_builder.py:184(_pokemon_numeric_into)
#     24414    0.029    0.000    0.517    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/_utils.py:823(_get_current_device_index)
#  6390/540    0.028    0.000    0.910    0.002 /content/p0/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1782(_call_impl)
#       135    0.027    0.000    0.200    0.001 /content/p0/src/model/fused_token_encoder.py:79(forward)
#       360    0.027    0.000    0.027    0.000 {method 'sum' of 'torch._C.TensorBase' objects}
#        90    0.026    0.000    0.026    0.000 {method 'logsumexp' of 'torch._C.TensorBase' objects}
#       540    0.026    0.000    1.581    0.003 /content/p0/src/model/observation_builder.py:92(_pokemon_categorical_into)
#      7343    0.023    0.000    0.035    0.000 /content/p0/.venv/lib/python3.13/site-packages/poke_env/battle/move.py:301(entry)
#     48828    0.023    0.000    0.023    0.000 {built-in method torch._C._cuda_getDeviceCount}
#     24414    0.022    0.000    0.305    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/_utils.py:790(_get_available_device_type)
#        90    0.022    0.000    0.022    0.000 {built-in method torch.softmax}
#     48828    0.021    0.000    0.021    0.000 {method 'encode' of 'str' objects}
#       180    0.021    0.000    0.021    0.000 {built-in method torch.floor_divide}
#       405    0.021    0.000    0.021    0.000 {built-in method torch.cat}
#     24414    0.020    0.000    0.779    0.000 /content/p0/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:612(__init__)
#     48828    0.020    0.000    0.020    0.000 {built-in method torch._C._cuda_isInBadFork}
#       135    0.019    0.000    0.019    0.000 {method 'max' of 'torch._C.TensorBase' objects}
#     24414    0.018    0.000    0.018    0.000 {built-in method torch._C._cuda_getDevice}
#        90    0.018    0.000    0.106    0.001 /content/p0/src/model/policy.py:295(_apply_top_p)
#     48828    0.018    0.000    0.018    0.000 {built-in method builtins.hasattr}
#
#
#
# ================================================================================
#
#
# ==================== Stage Breakdown for RL_Profiler ====================
# Total calls: 45
# Total measured time: 3.2740 s
# Avg time per call:   72.756 ms
#
# Stage                               | Total Time (s)  | Avg/Call (ms)   | Percentage
# -----------------------------------------------------------------------------------
# Tokenizer                           | 1.0543          | 23.429          | 32.2     %
# Observation Builder (non-tok)       | 0.6497          | 14.439          | 19.8     %
# Action Masking                      | 0.1076          | 2.391           | 3.3      %
# Tensor Prep / Device Transfer       | 0.0218          | 0.484           | 0.7      %
# Policy Encoding                     | 0.6818          | 15.151          | 20.8     %
# Policy Act / Top-P                  | 0.7525          | 16.723          | 23.0     %
# Post-processing                     | 0.0063          | 0.140           | 0.2      %
# ================================================================================
#
# [Showdown Server] Stopping Showdown server...
# [Showdown Server] Showdown server stopped.

# %%
# !cd p0 && uv run src/train/train_loop.py
# Out:
# 2026-06-10 19:56:56,044 [INFO] Using device: cuda
# 2026-06-10 19:57:06,475 [INFO] Building pokemon-showdown...
# 2026-06-10 19:57:12,372 [INFO] Pokemon-showdown built successfully.
# 2026-06-10 19:57:25,874 [INFO] All showdown servers are ready.
# 2026-06-10 19:57:26,493 [INFO] No checkpoint or seed policy found. Starting from random initialization.
# 2026-06-10 19:57:26,493 [INFO] Opponent pool empty, seeding with current policy as ep0
# 2026-06-10 19:57:29,667 [INFO] Opponent pool: OpponentPool(size=1/40, ids=['ep0'])
# 2026-06-10 20:00:11,591 [INFO] Ep 1/40 (T) | Pi: -0.0000 | V: 0.1916 | NormEnt: 84.92% | Clip: 0.00% | KL: 0.0000 | ATL: 15.1 | ATT: 0.32
# 2026-06-10 20:01:56,232 [INFO] Ep 2/40 (T) | Pi: -0.0001 | V: 0.1709 | NormEnt: 85.16% | Clip: 0.00% | KL: 0.0000 | ATL: 15.1 | ATT: 0.25
# 2026-06-10 20:03:38,613 [INFO] Ep 3/40 (T) | Pi: -0.0001 | V: 0.1959 | NormEnt: 84.82% | Clip: 0.00% | KL: 0.0000 | ATL: 14.8 | ATT: 0.23
# 2026-06-10 20:05:16,247 [INFO] Ep 4/40 (T) | Pi: -0.0001 | V: 0.1915 | NormEnt: 84.00% | Clip: 0.00% | KL: 0.0000 | ATL: 14.2 | ATT: 0.21
# 2026-06-10 20:06:53,153 [INFO] Ep 5/40 (T) | Pi: -0.0002 | V: 0.2057 | NormEnt: 85.08% | Clip: 0.00% | KL: 0.0000 | ATL: 15.2 | ATT: 0.21
# 2026-06-10 20:08:30,738 [INFO] Ep 6/40 (T) | Pi: -0.0002 | V: 0.1851 | NormEnt: 85.32% | Clip: 0.00% | KL: 0.0000 | ATL: 15.0 | ATT: 0.21
# 2026-06-10 20:10:08,325 [INFO] Ep 7/40 (T) | Pi: -0.0002 | V: 0.1782 | NormEnt: 85.22% | Clip: 0.00% | KL: 0.0000 | ATL: 14.9 | ATT: 0.22
# 2026-06-10 20:11:42,913 [INFO] Ep 8/40 (T) | Pi: -0.0003 | V: 0.1549 | NormEnt: 84.69% | Clip: 0.00% | KL: 0.0000 | ATL: 15.6 | ATT: 0.21
# 2026-06-10 20:13:18,368 [INFO] Ep 9/40 (T) | Pi: -0.0003 | V: 0.1550 | NormEnt: 84.66% | Clip: 0.00% | KL: 0.0000 | ATL: 15.5 | ATT: 0.21
# 2026-06-10 20:14:59,269 [INFO] Ep 10/40 (T) | Pi: -0.0004 | V: 0.1496 | NormEnt: 84.77% | Clip: 0.00% | KL: 0.0000 | ATL: 15.6 | ATT: 0.22
# 2026-06-10 20:15:01,018 [INFO] Checkpoint saved.
# 2026-06-10 20:58:26,820 [INFO] Ep 37/40 (T) | Pi: -0.0002 | V: 0.1685 | NormEnt: 80.00% | Clip: 0.00% | KL: 0.0000 | ATL: 14.0 | ATT: 0.21
# 2026-06-10 21:00:05,472 [INFO] Ep 38/40 (T) | Pi: -0.0001 | V: 0.1655 | NormEnt: 79.70% | Clip: 0.00% | KL: 0.0000 | ATL: 13.8 | ATT: 0.20
# 2026-06-10 21:01:43,652 [INFO] Ep 39/40 (T) | Pi: -0.0001 | V: 0.1634 | NormEnt: 80.05% | Clip: 0.00% | KL: 0.0000 | ATL: 14.5 | ATT: 0.21
# 2026-06-10 21:03:27,876 [INFO] Snapshot 'ep40' added to opponent pool. Pool: OpponentPool(size=3/40, ids=['ep0', 'ep20', 'ep40'])
# 2026-06-10 21:03:27,878 [INFO] Ep 40/40 (T) | Pi: -0.0002 | V: 0.1644 | NormEnt: 79.69% | Clip: 0.00% | KL: 0.0000 | ATL: 14.3 | ATT: 0.22
# 2026-06-10 21:03:44,571 [INFO] Checkpoint saved.
# 2026-06-10 21:03:45,265 [INFO] Training loop terminated successfully.

# %%
# !cd p0 &&  uv run bench/benchmark_policy_wr.py
# Out:
# [Showdown Server] Building pokemon-showdown in /content/p0/pokemon-showdown...
# [Showdown Server] Pokemon-showdown built successfully.
# [Showdown Server] Starting Showdown server on port 8000...
# [Showdown Server] Showdown server is ready on port 8000.
# Loading checkpoint from: checkpoints/ppo_checkpoint.pt
# Starting evaluation of policy against 4 bots (100 games each)...
# ============================================================
# Battling RL_Policy vs Random...
#   Result: 93.00% win rate
# Battling RL_Policy vs MaxBP...
#   Result: 37.00% win rate
# Battling RL_Policy vs SimpleH...
#   Result: 20.00% win rate
# Battling RL_Policy vs FuzzyH...
#   Result: 10.00% win rate
#
# ==============================
# Opponent        |   Win Rate
# ------------------------------
# Random          |     93.00%
# MaxBP           |     37.00%
# SimpleH         |     20.00%
# FuzzyH          |     10.00%
# ==============================
# [Showdown Server] Stopping Showdown server...
# [Showdown Server] Showdown server stopped.

# %%
# !cd p0 && uv run scripts/export_training.py --output "/content/drive/MyDrive/ppo_training_export.tar.gz" --verbose
# Out:
# Discovered 8 files to export (Total size: 1014.05 MB).
# Creating archive: /content/drive/MyDrive/ppo_training_export.tar.gz
# Adding: .ppoconfig (63.00 B)
# Adding: checkpoints/ppo_checkpoint.pt (507.03 MB)
# Adding: checkpoints/pool/ep0.pt (168.99 MB)
# Adding: checkpoints/pool/ep20.pt (168.99 MB)
# Adding: checkpoints/pool/ep40.pt (168.99 MB)
# Adding: checkpoints/pool/pool_state.json (163.00 B)
# Adding: training.log (6.43 KB)
# Adding: runs/ppo_training/events.out.tfevents.1781121446.f35001c2559d.3589.0 (39.62 KB)
# Export completed in 64.6s.
# Archive file: /content/drive/MyDrive/ppo_training_export.tar.gz (939.83 MB)
#
# To restore on the target machine, copy the archive to the 'p0/' directory and run:
#     tar -xzf ppo_training_export.tar.gz
