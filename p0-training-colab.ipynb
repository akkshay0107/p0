# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !curl -fsSL https://deb.nodesource.com/setup_20.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# 2026-06-09 18:46:07 - Installing pre-requisites
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,713 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,183 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,006 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Hit:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.3 MB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,489 kB]
# Hit:16 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,608 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,357 kB]
# Hit:19 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,050 kB]
# Fetched 42.4 MB in 4s (10.4 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 67 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.24).
# gnupg is already the newest version (2.2.27-3ubuntu2.5).
# gnupg set to manually installed.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 67 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 170 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 apt-transport-https all 2.4.14 [1,510 B]
# Fetched 1,510 B in 0s (36.4 kB/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 122403 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.14_all.deb ...
# Unpacking apt-transport-https (2.4.14) ...
# Setting up apt-transport-https (2.4.14) ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:6 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [14.7 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 26.8 kB in 1s (19.1 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 67 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 2026-06-09 18:46:29 - Repository configured successfully.
# 2026-06-09 18:46:29 - To install Node.js, run: apt install nodejs -y
# 2026-06-09 18:46:29 - You can use N|solid Runtime as a node.js alternative
# 2026-06-09 18:46:29 - To install N|solid Runtime, run: apt install nsolid -y
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 67 not upgraded.
# Need to get 32.2 MB of archives.
# After this operation, 196 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.20.2-1nodesource1 [32.2 MB]
# Fetched 32.2 MB in 1s (49.8 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 122407 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.20.2-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.20.2-1nodesource1) ...
# Setting up nodejs (20.20.2-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !node -v && npm -v
# Out:
# v20.20.2
# 10.8.2

# %%
# !pip install uv
# Out:
# Collecting uv
#   Downloading uv-0.11.19-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.11.19-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 61.5 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.11.19

# %%
# !git clone https://github.com/akkshay0107/p0.git
# Out:
# Cloning into 'p0'...
# remote: Enumerating objects: 1896, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 1896 (delta 14), reused 19 (delta 10), pack-reused 1842 (from 1)
# Receiving objects: 100% (1896/1896), 2.82 MiB | 7.16 MiB/s, done.
# Resolving deltas: 100% (1352/1352), done.

# %%
# !cd p0 && git checkout champions-port
# Out:
# Branch 'champions-port' set up to track remote branch 'champions-port' from 'origin'.
# Switched to a new branch 'champions-port'

# %%
# !cd p0 && git log -n 5
# Out:
# commit ae40352b151d173ee2814898dffc33f5a8080215 (HEAD -> champions-port, origin/champions-port)
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Tue Jun 9 23:28:04 2026 +0530
#
#     fix batch size and gradient scaling bug
#
# commit 464ce0419d969c9efaef9fa667ca3ef45128f75c
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Tue Jun 9 22:06:11 2026 +0530
#
#     fix opponent sampling in rollout
#
# commit 60e05fc4217f5af55cb604ab1175ee6f121f6f77
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Tue Jun 9 11:49:41 2026 +0530
#
#     update default values for ppo config
#
# commit 1ee26058479e95a5783c0ce7678d44011b4dcea9
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Tue Jun 9 01:24:25 2026 +0530
#
#     reduce redundant cloning in rollout collection
#
# commit f52bfae90f942254189fe331debc9b63d280f599
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Tue Jun 9 00:44:07 2026 +0530
#
#     conserve memory on gpu (chunk batches into multiple passes)

# %%
# !cd p0 && git submodule update --init --recursive
# Out:
# Submodule 'pokemon-showdown' (https://github.com/smogon/pokemon-showdown.git) registered for path 'pokemon-showdown'
# Cloning into '/content/p0/pokemon-showdown'...
# Submodule path 'pokemon-showdown': checked out 'd62d3a39878f7ef1c6e1cfbd84e8feb2ce7a9fdd'

# %%
# !cd p0/pokemon-showdown && npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠹⠸⠼⠴⠦npm warn deprecated npmlog@6.0.2: This package is no longer supported.
# ⠦⠧⠇⠏⠋⠙⠹⠸⠼npm warn deprecated are-we-there-yet@3.0.1: This package is no longer supported.
# ⠼⠴npm warn deprecated gauge@4.0.4: This package is no longer supported.
# ⠴npm warn deprecated @npmcli/move-file@1.1.2: This functionality has been moved to @npmcli/fs
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 355 packages, and audited 356 packages in 9s
# ⠼
# ⠼72 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# 23 vulnerabilities (3 low, 8 moderate, 12 high)
#
# To address issues that do not require attention, run:
#   npm audit fix
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠴

# %%
# !cd p0 && uv python install 3.13 && uv sync --extra cuda
# Out:
# Installed Python 3.13.13 in 1.71s
#  + cpython-3.13.13-linux-x86_64-gnu (python3.13)
# warning: `/root/.local/bin` is not on your PATH. To use installed Python executables, run `export PATH="/root/.local/bin:$PATH"` or `uv python update-shell`.
# Using CPython 3.13.13
# Creating virtual environment at: .venv
# Resolved 61 packages in 1ms
# Prepared 58 packages in 57.16s
# Installed 58 packages in 693ms
#  + absl-py==2.4.0
#  + certifi==2026.5.20
#  + charset-normalizer==3.4.7
#  + cloudpickle==3.1.2
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.4
#  + cuda-toolkit==13.0.2
#  + farama-notifications==0.0.6
#  + filelock==3.29.0
#  + fsspec==2026.4.0
#  + grpcio==1.80.0
#  + gymnasium==1.3.0
#  + idna==3.16
#  + iniconfig==2.3.0
#  + jinja2==3.1.6
#  + markdown==3.10.2
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.6
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
#  + nvidia-cusparse==12.6.3.3
#  + nvidia-cusparselt-cu13==0.8.1
#  + nvidia-nccl-cu13==2.29.7
#  + nvidia-nvjitlink==13.0.88
#  + nvidia-nvshmem-cu13==3.4.5
#  + nvidia-nvtx==13.0.85
#  + orjson==3.11.9
#  + p0==0.1.0 (from file:///content/p0)
#  + packaging==26.2
#  + pettingzoo==1.26.1
#  + pillow==12.2.0
#  + pluggy==1.6.0
#  + poke-env==0.15.0
#  + protobuf==7.35.0
#  + pygments==2.20.0
#  + pytest==9.0.3
#  + pytest-asyncio==1.4.0
#  + requests==2.34.2
#  + setuptools==81.0.0
#  + sympy==1.14.0
#  + tabulate==0.10.0
#  + tensorboard==2.20.0
#  + tensorboard-data-server==0.7.2
#  + torch==2.12.0
#  + triton==3.7.0
#  + typing-extensions==4.15.0
#  + urllib3==2.7.0
#  + websockets==16.0
#  + werkzeug==3.1.8

# %%
# %%writefile /content/p0/.ppoconfig
# num_episodes=10
# warmup_episodes=0
# lr=3e-4
# Out:
# Writing /content/p0/.ppoconfig

# %%
# !cd p0 && uv run src/train/train_loop.py
# Out:
# 2026-06-09 18:50:41,175 [INFO] Using device: cuda
# 2026-06-09 18:50:47,111 [INFO] Building pokemon-showdown...
# 2026-06-09 18:50:55,481 [INFO] Pokemon-showdown built successfully.
# 2026-06-09 18:51:09,033 [INFO] All showdown servers are ready.
# 2026-06-09 18:51:10,040 [INFO] No checkpoint or seed policy found. Starting from random initialization.
# 2026-06-09 18:51:10,040 [INFO] Opponent pool: OpponentPool(size=1/40, ids=['ep0'])
# 2026-06-09 18:53:55,635 [INFO] Ep 1/10 (T) | Pi: -0.0003 | V: 1.1903 | NormEnt: 84.86% | Clip: 0.00% | KL: 0.0000 | ATL: 14.2 | ATT: 0.31
# 2026-06-09 18:55:40,887 [INFO] Ep 2/10 (T) | Pi: -0.0011 | V: 1.0491 | NormEnt: 85.12% | Clip: 0.00% | KL: 0.0003 | ATL: 15.0 | ATT: 0.27
# 2026-06-09 18:57:28,828 [INFO] Ep 3/10 (T) | Pi: -0.0058 | V: 0.1493 | NormEnt: 84.17% | Clip: 4.08% | KL: 0.0042 | ATL: 15.1 | ATT: 0.26
# 2026-06-09 18:59:09,802 [INFO] Ep 4/10 (T) | Pi: -0.0041 | V: 0.1503 | NormEnt: 83.15% | Clip: 9.75% | KL: 0.0088 | ATL: 14.9 | ATT: 0.24
# 2026-06-09 19:00:46,290 [INFO] Ep 5/10 (T) | Pi: -0.0024 | V: 0.1419 | NormEnt: 82.24% | Clip: 1.48% | KL: 0.0025 | ATL: 14.8 | ATT: 0.22
# 2026-06-09 19:02:25,658 [INFO] Ep 6/10 (T) | Pi: -0.0047 | V: 0.1345 | NormEnt: 81.40% | Clip: 6.70% | KL: 0.0067 | ATL: 15.2 | ATT: 0.25
# 2026-06-09 19:04:07,913 [INFO] Ep 7/10 (T) | Pi: -0.0024 | V: 0.1337 | NormEnt: 79.64% | Clip: 1.11% | KL: 0.0021 | ATL: 15.1 | ATT: 0.24
# 2026-06-09 19:05:45,176 [INFO] Ep 8/10 (T) | Pi: -0.0013 | V: 0.1307 | NormEnt: 78.90% | Clip: 0.39% | KL: 0.0012 | ATL: 15.0 | ATT: 0.24
# 2026-06-09 19:07:25,362 [INFO] Ep 9/10 (T) | Pi: -0.0015 | V: 0.1300 | NormEnt: 77.54% | Clip: 0.18% | KL: 0.0011 | ATL: 15.1 | ATT: 0.24
# 2026-06-09 19:09:01,775 [INFO] Ep 10/10 (T) | Pi: -0.0013 | V: 0.1373 | NormEnt: 76.25% | Clip: 0.23% | KL: 0.0007 | ATL: 14.5 | ATT: 0.22
# 2026-06-09 19:09:13,658 [INFO] Checkpoint saved.
# 2026-06-09 19:09:14,165 [INFO] Training loop terminated successfully.

# %%
# !cd p0 && uv run scripts/export_training.py --output "/content/drive/MyDrive/ppo_training_export.tar.gz" --verbose
# Out:
# Discovered 5 files to export (Total size: 166.41 MB).
# Creating archive: /content/drive/MyDrive/ppo_training_export.tar.gz
# Adding: .ppoconfig (42.00 B)
# Adding: checkpoints/pool/ep0.pt (166.38 MB)
# Adding: checkpoints/pool/pool_state.json (74.00 B)
# Adding: training.log (33.32 KB)
# Adding: runs/ppo_training/events.out.tfevents.1781030950.8d31ab8d4809.4255.0 (88.00 B)
# Export completed in 18.7s.
# Archive file: /content/drive/MyDrive/ppo_training_export.tar.gz (153.93 MB)
#
# To restore on the target machine, copy the archive to the 'p0/' directory and run:
#     tar -xzf ppo_training_export.tar.gz
