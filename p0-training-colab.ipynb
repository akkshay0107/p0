# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !curl -fsSL https://deb.nodesource.com/setup_20.x | sudo -E bash -
# !sudo apt-get install -y nodejs
# Out:
# 2026-06-12 07:43:12 - Installing pre-requisites
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,721 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !node -v && npm -v
# Out:
# v20.20.2
# 10.8.2

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 61.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/akkshay0107/p0.git
# Out:
# Cloning into 'p0'...
# remote: Enumerating objects: 2153, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 2153 (delta 208), reused 151 (delta 86), pack-reused 1842 (from 1)
# Receiving objects: 100% (2153/2153), 2.95 MiB | 13.35 MiB/s, done.
# Resolving deltas: 100% (1546/1546), done.

# %%
# !cd p0 && git checkout champions-port
# Out:
# Branch 'champions-port' set up to track remote branch 'champions-port' from 'origin'.
# Switched to a new branch 'champions-port'

# %%
# !cd p0 && git log -n 5
# Out:
# commit 7abb4010d6764b6f01a2c909e413c727c4ab0014 (HEAD -> champions-port, origin/champions-port)
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Fri Jun 12 13:12:34 2026 +0530
#
#     reduce initial scale of gradscaler, log scale on inf grad
#
# commit 8e974f22b4d80e12259a44f13f17d746778c490b
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Fri Jun 12 12:50:41 2026 +0530
#
#     more dtype fixes, patch login timeout
#
# commit 92c6e87931f2481ff157053e3fa1073b8857ed40
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Fri Jun 12 11:31:55 2026 +0530
#
#     bias history gate default
#
# commit c5561a43b70f93860f0ba16c8385f8b2383e2e93
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Fri Jun 12 11:05:23 2026 +0530
#
#     add more detail to aux move path, fix compile issues
#
# commit a334bbc190d1ae964788cde63d92b110d014c14e
# Author: Akkshay Sundara Rajan <sundar57@purdue.edu>
# Date:   Fri Jun 12 00:53:57 2026 +0530
#
# ...

# %%
# !cd p0 && git submodule update --init --recursive
# Out:
# Submodule 'pokemon-showdown' (https://github.com/smogon/pokemon-showdown.git) registered for path 'pokemon-showdown'
# Cloning into '/content/p0/pokemon-showdown'...
# Submodule path 'pokemon-showdown': checked out 'd62d3a39878f7ef1c6e1cfbd84e8feb2ce7a9fdd'

# %%
# !cd p0/pokemon-showdown && npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠏⠋⠙⠹npm warn deprecated npmlog@6.0.2: This package is no longer supported.
# ⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹npm warn deprecated are-we-there-yet@3.0.1: This package is no longer supported.
# ⠹⠸npm warn deprecated @npmcli/move-file@1.1.2: This functionality has been moved to @npmcli/fs
# ⠼npm warn deprecated gauge@4.0.4: This package is no longer supported.
# ⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 355 packages, and audited 356 packages in 9s
# ⠙
# ⠙72 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙
# 23 vulnerabilities (3 low, 8 moderate, 12 high)
#
# To address issues that do not require attention, run:
#   npm audit fix
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠹

# %%
# !cd p0 && uv python install 3.13 && uv sync --extra cuda
# Out:
# Installed Python 3.13.14 in 1.32s
#  + cpython-3.13.14-linux-x86_64-gnu (python3.13)
# ...
# Using CPython 3.13.14
# Creating virtual environment at: .venv
# Resolved 61 packages in 0.96ms
# Prepared 58 packages in 1m 00s
# Installed 58 packages in 750ms
#  + absl-py==2.4.0
#  + certifi==2026.5.20
#  + charset-normalizer==3.4.7
#  + cloudpickle==3.1.2
#  + cuda-bindings==13.2.0
#  + cuda-pathfinder==1.5.4
#  + cuda-toolkit==13.0.2
#  + farama-notifications==0.0.6
#  + filelock==3.29.0
#  + fsspec==2026.4.0
#  + grpcio==1.80.0
#  + gymnasium==1.3.0
#  + idna==3.16
#  + iniconfig==2.3.0
#  + jinja2==3.1.6
#  + markdown==3.10.2
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.6.1
#  + numpy==2.4.6
#  + nvidia-cublas==13.1.1.3
#  + nvidia-cuda-cupti==13.0.85
#  + nvidia-cuda-nvrtc==13.0.88
#  + nvidia-cuda-runtime==13.0.96
#  + nvidia-cudnn-cu13==9.20.0.48
#  + nvidia-cufft==12.0.0.61
#  + nvidia-cufile==1.15.1.6
#  + nvidia-curand==10.4.0.35
#  + nvidia-cusolver==12.0.4.66
# ...

# %%
# %%writefile /content/p0/.ppoconfig
# num_episodes=40
# warmup_episodes=0
# lr=3e-5
# snapshot_interval=20
# enable_optim=true
# Out:
# Writing /content/p0/.ppoconfig

# %%
! cd p0 && uv run bench/benchmark_action_time.py
# Out:
# [Showdown Server] Building pokemon-showdown in /content/p0/pokemon-showdown...
# [Showdown Server] Pokemon-showdown built successfully.
# [Showdown Server] Starting Showdown server on port 8000...
# [Showdown Server] Showdown server is ready on port 8000.
# Using device: cuda
# Starting 5 battles to profile the forward pass...
#
# ==================== cProfile Results for RL_Profiler ====================
# Total _get_action calls: 43
#          348988 function calls (336575 primitive calls) in 1.438 seconds
#
#    Ordered by: internal time
#    List reduced from 353 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2580    0.164    0.000    0.164    0.000 {built-in method torch._C._nn.linear}
#       731    0.120    0.000    0.120    0.000 {built-in method torch.embedding}
#        86    0.089    0.001    0.243    0.003 /content/p0/src/model/policy.py:199(_compute_pointer_logits)
# ...

# %%
# !cd p0 && uv run src/train/train_loop.py
# Out:
# 2026-06-12 07:47:34,778 [INFO] Using device: cuda
# 2026-06-12 07:47:41,670 [INFO] Compiling rollout actor for reduce-overhead...
# 2026-06-12 07:47:50,095 [INFO] Building pokemon-showdown...
# 2026-06-12 07:47:58,121 [INFO] Pokemon-showdown built successfully.
# 2026-06-12 07:48:12,275 [INFO] All showdown servers are ready.
# 2026-06-12 07:48:14,020 [INFO] No checkpoint or seed policy found. Starting from random initialization.
# 2026-06-12 07:48:14,020 [INFO] Opponent pool empty, seeding with current policy as ep0
# 2026-06-12 07:48:16,731 [INFO] Opponent pool: OpponentPool(size=1/40, ids=['ep0'])
# W0612 07:49:40.539000 4646 torch/_inductor/utils.py:1717] [2/0_1] Not enough SMs to use max_autotune_gemm mode
# 2026-06-12 07:52:11,228 [INFO] Ep 1/40 (T) | Pi: -0.0001 | V: 0.2343 | NormEnt: 84.92% | Clip: 0.00% | KL: 0.0000 | ATL: 14.9 | ATT: 0.59
# 2026-06-12 07:53:14,691 [WARNING] Non-finite grad norm detected; scaler will skip this step (loss scale=4096)
# ...

# %%
# !cd p0 &&  uv run bench/benchmark_policy_wr.py
# Out:
# [Showdown Server] Building pokemon-showdown in /content/p0/pokemon-showdown...
# [Showdown Server] Pokemon-showdown built successfully.
# [Showdown Server] Starting Showdown server on port 8000...
# [Showdown Server] Showdown server is ready on port 8000.
# Loading checkpoint from: checkpoints/ppo_checkpoint.pt
# Starting evaluation of policy against 4 bots (100 games each)...
# ...
# Battling RL_Policy vs Random...
#   Result: 94.00% win rate
# Battling RL_Policy vs MaxBP...
#   Result: 38.00% win rate
# Battling RL_Policy vs SimpleH...
#   Result: 26.00% win rate
# Battling RL_Policy vs FuzzyH...
#   Result: 9.00% win rate
#
# ...
# Opponent        |   Win Rate
# ------------------------------
# Random          |     94.00%
# MaxBP           |     38.00%
# SimpleH         |     26.00%
# FuzzyH          |      9.00%
# ...
# [Showdown Server] Stopping Showdown server...
# [Showdown Server] Showdown server stopped.

# %%
# !cd p0 && uv run scripts/export_training.py --output "/content/drive/MyDrive/ppo_training_export.tar.gz" --verbose
# Out:
# Discovered 8 files to export (Total size: 1016.91 MB).
# Creating archive: /content/drive/MyDrive/ppo_training_export.tar.gz
# Adding: .ppoconfig (81.00 B)
# Adding: checkpoints/ppo_checkpoint.pt (508.45 MB)
# Adding: checkpoints/pool/ep0.pt (169.47 MB)
# Adding: checkpoints/pool/ep20.pt (169.47 MB)
# Adding: checkpoints/pool/ep40.pt (169.47 MB)
# Adding: checkpoints/pool/pool_state.json (164.00 B)
# Adding: training.log (7.04 KB)
# Adding: runs/ppo_training/events.out.tfevents.1781250493.119637c9056c.4646.0 (39.62 KB)
# Export completed in 57.8s.
# Archive file: /content/drive/MyDrive/ppo_training_export.tar.gz (940.10 MB)
#
# To restore on the target machine, copy the archive to the 'p0/' directory and run:
#     tar -xzf ppo_training_export.tar.gz
